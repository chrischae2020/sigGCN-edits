# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Github/sigGCN-main/data/BaronHuman/
# Out:
# /content/gdrive/MyDrive/Github/sigGCN-main/data/BaronHuman

# %%
import pandas as pd
df = pd.read_csv('Labels.csv')
sorted(df['x'].unique())
# Out:
# ['acinar',
#  'activated_stellate',
#  'alpha',
#  'beta',
#  'delta',
#  'ductal',
#  'endothelial',
#  'epsilon',
#  'gamma',
#  'macrophage',
#  'mast',
#  'quiescent_stellate',
#  'schwann',
#  't_cell']
